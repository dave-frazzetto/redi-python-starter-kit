# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Introduction to data manipulation and visualisation with Pandas

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Introduction
#
# pandas is a library written for the Python for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.
#
# So since it's a module, we need to import it on our notebook

# %%
# importing pandas
import pandas as pd

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Basic data exploration
#
# - Reading data
# - Selecting columns
# - selecting rows

# %%
# reading a .csv file with pandas, using `Id` as the index column
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
type(df)
# pandas represents data in a tabular form known as DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Selecting Columns
# * Two ways
#     - `df['col_name']` or `df[[array of cols]]`
#     - `df.col_name` (auto complete feature works 🙂)

# %%
df['LotFrontage']
# Out:
# Id
# 1       65.0
# 2       80.0
# 3       68.0
# 4       60.0
# 5       84.0
#         ...
# 1456    62.0
# 1457    85.0
# 1458    66.0
# 1459    68.0
# 1460    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
type(df['LotFrontage'])
# each column of a dataframe is known as Series
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Till now we saw that pandas only work with 2 data structures
# - DataFrame
# - Series

# %%
# for multiple column selection, provide the array of columns
cols = ['LotFrontage', 'SalePrice', 'LotShape']
df[cols]
# Out:
#       LotFrontage  SalePrice LotShape
# Id
# 1            65.0     208500      Reg
# 2            80.0     181500      Reg
# 3            68.0     223500      IR1
# 4            60.0     140000      IR1
# 5            84.0     250000      IR1
# ...           ...        ...      ...
# 1456         62.0     175000      Reg
# 1457         85.0     210000      Reg
# 1458         66.0     266500      Reg
# 1459         68.0     142125      Reg
# 1460         75.0     147500      Reg
#
# [1460 rows x 3 columns]

# %%
df.SalePrice
# Out:
# Id
# 1       208500
# 2       181500
# 3       223500
# 4       140000
# 5       250000
#          ...
# 1456    175000
# 1457    210000
# 1458    266500
# 1459    142125
# 1460    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# .shape attribute will give you the (rows, columns) of a dataframe
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Some basic functions for data exploration

# %%
# selecting top 10, rows in a dataframe (by default it'll give you top 5 rows)
df.head(10)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 6          Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
# 7          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 8          Lvl    AllPub    Corner  ...        0    NaN    NaN        Shed
# 9          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 10         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
# 6      700     10    2009        WD         Normal     143000
# 7        0      8    2007        WD         Normal     307000
# 8      350     11    2009        WD         Normal     200000
# 9        0      4    2008        WD        Abnorml     129900
# 10       0      1    2008        WD         Normal     118000
#
# [10 rows x 80 columns]

# %%
# selecting last 10 rows of dataframe (by default it'll give last 5 rows)
df.tail(10)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1451         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1452         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1453         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1454         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1455         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1451       0      9    2009        WD         Normal     136000
# 1452       0      5    2009       New        Partial     287090
# 1453       0      5    2006        WD         Normal     145000
# 1454       0      7    2006        WD        Abnorml      84500
# 1455       0     10    2009        WD         Normal     185000
# 1456       0      8    2007        WD         Normal     175000
# 1457       0      2    2010        WD         Normal     210000
# 1458    2500      5    2010        WD         Normal     266500
# 1459       0      4    2010        WD         Normal     142125
# 1460       0      6    2008        WD         Normal     147500
#
# [10 rows x 80 columns]

# %%
# selecting randomly 10 rows in dataframe
df.sample(10)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1166          20       RL         79.0     9541   Pave   NaN      IR1
# 1107          20       RL        114.0    10357   Pave   NaN      IR1
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 896           60       RL         71.0     7056   Pave   NaN      Reg
# 118           20       RL         74.0     8536   Pave   NaN      Reg
# 932           20       RL         70.0     9100   Pave   NaN      Reg
# 422           20       RL          NaN    16635   Pave   NaN      IR1
# 121           80       RL          NaN    21453   Pave   NaN      IR1
# 1317          20       RL         61.0    10226   Pave   NaN      IR1
# 1002          30       RL         60.0     5400   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1166         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1107         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 9            Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 896          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 118          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 932          Lvl    AllPub    Inside  ...        0    NaN  GdWo         NaN
# 422          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 121          Low    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 1317         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1002         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1166       0      9    2009       New        Partial     233170
# 1107       0      5    2007        WD         Normal     179900
# 9          0      4    2008        WD        Abnorml     129900
# 896        0     10    2008        WD         Normal     140000
# 118        0      4    2007       New        Partial     155000
# 932        0      7    2009        WD         Normal     117500
# 422        0      6    2009        WD         Normal     215000
# 121        0     10    2006        WD         Normal     180000
# 1317       0      1    2009        WD         Normal     295493
# 1002       0      1    2007        WD        Abnorml      86000
#
# [10 rows x 80 columns]

# %%
# getting array of all the present column names in dataframe
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Selecting Rows
# * 2 ways
#     - `df.loc[]`
#     - `df.iloc[]`

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
# selecting a particular row with it's index name
df.loc[2]
# Out:
# MSSubClass           20
# MSZoning             RL
# LotFrontage        80.0
# LotArea            9600
# Street             Pave
#                   ...
# MoSold                5
# YrSold             2007
# SaleType             WD
# SaleCondition    Normal
# SalePrice        181500
# Name: 2, Length: 80, dtype: object

# %%
# ignore this code for this moment, we'll discuss it later
d = df.groupby('LotConfig').count()
d.head()
# Out:
#            MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# LotConfig
# Corner            263       263          201      263     263     15
# CulDSac            94        94           45       94      94      0
# FR2                47        47           33       47      47      0
# FR3                 4         4            4        4       4      0
# Inside           1052      1052          918     1052    1052     76
#
#            LotShape  LandContour  Utilities  LandSlope  ...  PoolArea  PoolQC  \
# LotConfig                                               ...
# Corner          263          263        263        263  ...       263       3
# CulDSac          94           94         94         94  ...        94       1
# FR2              47           47         47         47  ...        47       0
# FR3               4            4          4          4  ...         4       0
# Inside         1052         1052       1052       1052  ...      1052       3
#
#            Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  \
# LotConfig
# Corner        64           12      263     263     263       263
# CulDSac       15            3       94      94      94        94
# FR2            7            2       47      47      47        47
# FR3            0            0        4       4       4         4
# Inside       195           37     1052    1052    1052      1052
#
#            SaleCondition  SalePrice
# LotConfig
# Corner               263        263
# CulDSac               94         94
# FR2                   47         47
# FR3                    4          4
# Inside              1052       1052
#
# [5 rows x 79 columns]

# %%
# NOTE: pass the index's name (here we have index as string)
d.loc['Inside']
# Out:
# MSSubClass       1052
# MSZoning         1052
# LotFrontage       918
# LotArea          1052
# Street           1052
#                  ...
# MoSold           1052
# YrSold           1052
# SaleType         1052
# SaleCondition    1052
# SalePrice        1052
# Name: Inside, Length: 79, dtype: int64

# %%
# .loc also takes the name of column or array of columns for showing the selective columns
df.loc[2, 'SalePrice']
# Out:
# 181500

# %%
cols = ['LotConfig', 'SalePrice', 'Street']
df.loc[2, cols]
# Out:
# LotConfig       FR2
# SalePrice    181500
# Street         Pave
# Name: 2, dtype: object

# %%
# .iloc takes the sequential order of certain row (pandas count from 0)
d.iloc[4]
# Out:
# MSSubClass       1052
# MSZoning         1052
# LotFrontage       918
# LotArea          1052
# Street           1052
#                  ...
# MoSold           1052
# YrSold           1052
# SaleType         1052
# SaleCondition    1052
# SalePrice        1052
# Name: Inside, Length: 79, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### Conditional selection of rows

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
# selecting rows where MSSubClass value is equal to 20
single_condition = df['MSSubClass'] == 20
single_condition # boolean array with True where condition met and False otherwise
# Out:
# Id
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
#         ...
# 1456    False
# 1457     True
# 1458    False
# 1459     True
# 1460     True
# Name: MSSubClass, Length: 1460, dtype: bool

# %% [markdown]
# ### multiple condition:
# - & => and
# - | => or
# - ! => not

# %%
# selecting rows where 'LotConfig' is 'FR2' and MSSubClass is 20
multiple_condition = ((df['LotConfig'] == 'FR2') & (df['MSSubClass'] == 20))

# %%
# passing those boolean arrays will show you that rows where conditon is met
df[multiple_condition]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 141           20       RL         70.0    10500   Pave   NaN      Reg
# 224           20       RL         70.0    10500   Pave   NaN      Reg
# 229           20       RL         70.0     8521   Pave   NaN      Reg
# 237           20       RL         65.0     8773   Pave   NaN      Reg
# 422           20       RL          NaN    16635   Pave   NaN      IR1
# 481           20       RL         98.0    16033   Pave   NaN      IR1
# 538           20       RL          NaN    12735   Pave   NaN      IR1
# 806           20       RL         91.0    12274   Pave   NaN      IR1
# 934           20       RL         63.0     8487   Pave   NaN      Reg
# 995           20       RL         96.0    12456   Pave   NaN      Reg
# 1118          20       RL         57.0     9764   Pave   NaN      IR1
# 1159          20       RL         92.0    11932   Pave   NaN      Reg
# 1260          20       RL         65.0     9750   Pave   NaN      Reg
# 1370          20       RL         48.0    10635   Pave   NaN      IR2
# 1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1445          20       RL         63.0     8500   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 141          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 224          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 229          Lvl    AllPub       FR2  ...        0    NaN  MnPrv         NaN
# 237          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 422          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 481          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 538          Lvl    AllPub       FR2  ...        0    NaN   MnWw         NaN
# 806          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 934          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 995          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1118         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1159         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1260         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1370         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1437         Lvl    AllPub       FR2  ...        0    NaN   GdWo         NaN
# 1438         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1445         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2          0      5    2007        WD         Normal     181500
# 141        0      4    2010     ConLI         Normal     115000
# 224        0      3    2009        WD        Abnorml      97000
# 229        0      5    2010        WD         Normal     125000
# 237        0      5    2010        WD         Normal     185500
# 422        0      6    2009        WD         Normal     215000
# 481        0      3    2006        WD         Normal     326000
# 538        0      4    2008       COD         Normal     111250
# 806        0      7    2008       New        Partial     227680
# 934        0      8    2009        WD         Normal     190000
# 995        0      7    2009        WD         Normal     337500
# 1118       0      5    2008        WD         Normal     130000
# 1159       0      6    2008     ConLD        Partial     235128
# 1260       0      7    2008        WD         Normal     151000
# 1370       0      5    2010        WD         Normal     232000
# 1437       0      5    2007        WD         Normal     120500
# 1438       0     11    2008       New        Partial     394617
# 1445       0     11    2007        WD         Normal     179600
#
# [18 rows x 80 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Getting some insights of data

# %%
# gives basic information about columns in dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     1452 non-null   object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
#  79  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 956.2+ KB

# %%
# gives statistical information about columns of dataframe
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
# returns the data type for each column
df.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 80, dtype: object

# %%
# showing unique values and their frequencey in a column
df.LotConfig.value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
# showing the number of unique values in a column
df.LotConfig.nunique()
# Out:
# 5

# %%
# finding nan values
df.isna() # or
df.isnull() (both works same)
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1          False     False        False    False   False   True     False
# 2          False     False        False    False   False   True     False
# 3          False     False        False    False   False   True     False
# 4          False     False        False    False   False   True     False
# 5          False     False        False    False   False   True     False
# ...          ...       ...          ...      ...     ...    ...       ...
# 1456       False     False        False    False   False   True     False
# 1457       False     False        False    False   False   True     False
# 1458       False     False        False    False   False   True     False
# 1459       False     False        False    False   False   True     False
# 1460       False     False        False    False   False   True     False
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                       ...
# 1           False      False      False  ...     False    True   True
# 2           False      False      False  ...     False    True   True
# 3           False      False      False  ...     False    True   True
# 4           False      False      False  ...     False    True   True
# 5           False      False      False  ...     False    True   True
# ...           ...        ...        ...  ...       ...     ...    ...
# 1456        False      False      False  ...     False    True   True
# 1457        False      False      False  ...     False    True  False
# 1458        False      False      False  ...     False    True  False
# 1459        False      False      False  ...     False    True   True
# 1460        False      False      False  ...     False    True   True
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1            True    False   False   False     False          False      False
# 2            True    False   False   False     False          False      False
# 3            True    False   False   False     False          False      False
# 4            True    False   False   False     False          False      False
# 5            True    False   False   False     False          False      False
# ...           ...      ...     ...     ...       ...            ...        ...
# 1456         True    False   False   False     False          False      False
# 1457         True    False   False   False     False          False      False
# 1458        False    False   False   False     False          False      False
# 1459         True    False   False   False     False          False      False
# 1460         True    False   False   False     False          False      False
#
# [1460 rows x 80 columns]

# %%
# counting total number of nan values in a dataframe
df.isna().values.sum() # try to find why it worked, if you have doubt leave a comment ?
# Out:
# 6965

# %%
df.isna().sum()[:10]
# Out:
# MSSubClass        0
# MSZoning          0
# LotFrontage     259
# LotArea           0
# Street            0
# Alley          1369
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Dealing with Date/Time in Pandas
#
# Sometime we have data in which a particular column contains date as values, but those values are of object data type initially.
# So we had to convert them into datetime format.

# %%
new_df = pd.read_csv('../input/dataset/QueryResults.csv')
new_df.head()
# Out:
#                   Date         Tag  Posts
# 0  2008-07-01 00:00:00          c#      3
# 1  2008-08-01 00:00:00    assembly      8
# 2  2008-08-01 00:00:00  javascript    162
# 3  2008-08-01 00:00:00           c     85
# 4  2008-08-01 00:00:00      python    124

# %%
# see we have `date` column as type of object
new_df.dtypes
# Out:
# Date     object
# Tag      object
# Posts     int64
# dtype: object

# %%
# converting `Date` column from object to `datetime` format
df.Date = pd.to_datetime(df.Date)

# %%
new_df.head()
# Out:
#         Date         Tag  Posts
# 0 2008-07-01          c#      3
# 1 2008-08-01    assembly      8
# 2 2008-08-01  javascript    162
# 3 2008-08-01           c     85
# 4 2008-08-01      python    124

# %%
# well it worked :)
new_df.dtypes
# Out:
# Date     datetime64[ns]
# Tag              object
# Posts             int64
# dtype: object

# %%
# a shorter way to do the same, `parse_date` parameter takes the array of column name that contain Dates as values
new_df = pd.read_csv('../input/dataset/QueryResults.csv', parse_dates=['Date'])
new_df.head()
# Out:
#         Date         Tag  Posts
# 0 2008-07-01          c#      3
# 1 2008-08-01    assembly      8
# 2 2008-08-01  javascript    162
# 3 2008-08-01           c     85
# 4 2008-08-01      python    124

# %%
new_df.dtypes
# Out:
# Date     datetime64[ns]
# Tag              object
# Posts             int64
# dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Dropping Stuff
# - Droping a column
# - Droping a row
# - Droping `nan` values (we have a particular section for treatment of `nan` values)

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
# dropping entire `SalePrice` column from dataframe,
# remember axis=1 represents that we are moving along column and dropping its values
df = df.drop('SalePrice', axis=1)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2            Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# 3            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 4            Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 5            Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 1456         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub    Inside  ...           0        0    NaN  GdPrv
# 1459         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1460         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1            NaN       0       2    2008        WD         Normal
# 2            NaN       0       5    2007        WD         Normal
# 3            NaN       0       9    2008        WD         Normal
# 4            NaN       0       2    2006        WD        Abnorml
# 5            NaN       0      12    2008        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 1456         NaN       0       8    2007        WD         Normal
# 1457         NaN       0       2    2010        WD         Normal
# 1458        Shed    2500       5    2010        WD         Normal
# 1459         NaN       0       4    2010        WD         Normal
# 1460         NaN       0       6    2008        WD         Normal
#
# [1460 rows x 79 columns]

# %%
# dropping multiple columns
columns_to_drop = ['SalePrice', 'LotArea']
df.drop(columns_to_drop, axis=1)
# Out:
#       MSSubClass MSZoning  LotFrontage Street Alley LotShape LandContour  \
# Id
# 1             60       RL         65.0   Pave   NaN      Reg         Lvl
# 2             20       RL         80.0   Pave   NaN      Reg         Lvl
# 3             60       RL         68.0   Pave   NaN      IR1         Lvl
# 4             70       RL         60.0   Pave   NaN      IR1         Lvl
# 5             60       RL         84.0   Pave   NaN      IR1         Lvl
# ...          ...      ...          ...    ...   ...      ...         ...
# 1456          60       RL         62.0   Pave   NaN      Reg         Lvl
# 1457          20       RL         85.0   Pave   NaN      Reg         Lvl
# 1458          70       RL         66.0   Pave   NaN      Reg         Lvl
# 1459          20       RL         68.0   Pave   NaN      Reg         Lvl
# 1460          20       RL         75.0   Pave   NaN      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                  ...
# 1       AllPub    Inside       Gtl  ...           0        0    NaN    NaN
# 2       AllPub       FR2       Gtl  ...           0        0    NaN    NaN
# 3       AllPub    Inside       Gtl  ...           0        0    NaN    NaN
# 4       AllPub    Corner       Gtl  ...           0        0    NaN    NaN
# 5       AllPub       FR2       Gtl  ...           0        0    NaN    NaN
# ...        ...       ...       ...  ...         ...      ...    ...    ...
# 1456    AllPub    Inside       Gtl  ...           0        0    NaN    NaN
# 1457    AllPub    Inside       Gtl  ...           0        0    NaN  MnPrv
# 1458    AllPub    Inside       Gtl  ...           0        0    NaN  GdPrv
# 1459    AllPub    Inside       Gtl  ...           0        0    NaN    NaN
# 1460    AllPub    Inside       Gtl  ...           0        0    NaN    NaN
#
#      MiscFeature  MiscVal  MoSold  YrSold  SaleType SaleCondition
# Id
# 1            NaN        0       2    2008        WD        Normal
# 2            NaN        0       5    2007        WD        Normal
# 3            NaN        0       9    2008        WD        Normal
# 4            NaN        0       2    2006        WD       Abnorml
# 5            NaN        0      12    2008        WD        Normal
# ...          ...      ...     ...     ...       ...           ...
# 1456         NaN        0       8    2007        WD        Normal
# 1457         NaN        0       2    2010        WD        Normal
# 1458        Shed     2500       5    2010        WD        Normal
# 1459         NaN        0       4    2010        WD        Normal
# 1460         NaN        0       6    2008        WD        Normal
#
# [1460 rows x 78 columns]

# %%
# dropping rows,
# axis=0 represents that now we are moving along rows and dropping the values
df.drop([1,5], axis=0)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 7             20       RL         75.0    10084   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 6            Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
# 7            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 6        700     10    2009        WD         Normal     143000
# 7          0      8    2007        WD         Normal     307000
# ...      ...    ...     ...       ...            ...        ...
# 1456       0      8    2007        WD         Normal     175000
# 1457       0      2    2010        WD         Normal     210000
# 1458    2500      5    2010        WD         Normal     266500
# 1459       0      4    2010        WD         Normal     142125
# 1460       0      6    2008        WD         Normal     147500
#
# [1458 rows x 80 columns]

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 5          0     12    2008        WD         Normal     250000
# ...      ...    ...     ...       ...            ...        ...
# 1456       0      8    2007        WD         Normal     175000
# 1457       0      2    2010        WD         Normal     210000
# 1458    2500      5    2010        WD         Normal     266500
# 1459       0      4    2010        WD         Normal     142125
# 1460       0      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Dealing with `nan` values
#
# In Pandas there are two ways in which you can deal `nan` values :
# - drop the rows / columns that contain `nan` value
# - replace that `nan` value with some other value

# %%
# dropping rows with nan values, by default axis=0
df['LotArea'].dropna()
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %% [markdown]
# unfortunately all of the rows in our data contain a `nan` value

# %%
# dropping columns with nan values
dd = df.dropna(axis=1)

# %%
dd.isna().values.any()
# Out:
# False

# %%
# replacing nan values with another numerical value
df = df.fillna('True')
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave     0      Reg
# 2             20       RL         80.0     9600   Pave     0      Reg
# 3             60       RL         68.0    11250   Pave     0      IR1
# 4             70       RL         60.0     9550   Pave     0      IR1
# 5             60       RL         84.0    14260   Pave     0      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave     0      Reg
# 1457          20       RL         85.0    13175   Pave     0      Reg
# 1458          70       RL         66.0     9042   Pave     0      Reg
# 1459          20       RL         68.0     9717   Pave     0      Reg
# 1460          20       RL         75.0     9937   Pave     0      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0      0      0           0
# 2            Lvl    AllPub       FR2  ...        0      0      0           0
# 3            Lvl    AllPub    Inside  ...        0      0      0           0
# 4            Lvl    AllPub    Corner  ...        0      0      0           0
# 5            Lvl    AllPub       FR2  ...        0      0      0           0
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1456         Lvl    AllPub    Inside  ...        0      0      0           0
# 1457         Lvl    AllPub    Inside  ...        0      0  MnPrv           0
# 1458         Lvl    AllPub    Inside  ...        0      0  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0      0      0           0
# 1460         Lvl    AllPub    Inside  ...        0      0      0           0
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 5          0     12    2008        WD         Normal     250000
# ...      ...    ...     ...       ...            ...        ...
# 1456       0      8    2007        WD         Normal     175000
# 1457       0      2    2010        WD         Normal     210000
# 1458    2500      5    2010        WD         Normal     266500
# 1459       0      4    2010        WD         Normal     142125
# 1460       0      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %%
filtered_df.isna().values.any()
# Out:
# False

# %% [markdown]
# Is the method that shown is really helpful 🤔 ?
#
# The problem with above method is that if our column will be of type object but still it got filled with a numerical value

# %% [markdown]
# A correct way is to provide the coloumn name and value to replace with `nan`
#
# for example:
# let `column1` is a numerical column and `column2` is a object column
# ```python
# df.fillna({
#     'coloumn1' : 0
#     'column2': 'missing',
# })
# ```
# now it'll replace the `nan` values in `column1` with 0 and `column2` with 'missing'

# %%
filling = {}
for col in df.columns:
    if df[col].dtype == object:
        filling[col] = "missing"
    else:
        filling[col] = 0
filling
# Out:
# {'MSSubClass': 0,
#  'MSZoning': 'missing',
#  'LotFrontage': 0,
#  'LotArea': 0,
#  'Street': 'missing',
#  'Alley': 'missing',
#  'LotShape': 'missing',
#  'LandContour': 'missing',
#  'Utilities': 'missing',
#  'LotConfig': 'missing',
#  'LandSlope': 'missing',
#  'Neighborhood': 'missing',
#  'Condition1': 'missing',
#  'Condition2': 'missing',
#  'BldgType': 'missing',
#  'HouseStyle': 'missing',
#  'OverallQual': 0,
#  'OverallCond': 0,
#  'YearBuilt': 0,
#  'YearRemodAdd': 0,
#  'RoofStyle': 'missing',
#  'RoofMatl': 'missing',
#  'Exterior1st': 'missing',
#  'Exterior2nd': 'missing',
#  'MasVnrType': 'missing',
#  'MasVnrArea': 0,
#  'ExterQual': 'missing',
#  'ExterCond': 'missing',
#  'Foundation': 'missing',
#  'BsmtQual': 'missing',
#  'BsmtCond': 'missing',
#  'BsmtExposure': 'missing',
#  'BsmtFinType1': 'missing',
#  'BsmtFinSF1': 0,
#  'BsmtFinType2': 'missing',
#  'BsmtFinSF2': 0,
#  'BsmtUnfSF': 0,
#  'TotalBsmtSF': 0,
#  'Heating': 'missing',
#  'HeatingQC': 'missing',
#  'CentralAir': 'missing',
#  'Electrical': 'missing',
#  '1stFlrSF': 0,
#  '2ndFlrSF': 0,
#  'LowQualFinSF': 0,
#  'GrLivArea': 0,
#  'BsmtFullBath': 0,
#  'BsmtHalfBath': 0,
#  'FullBath': 0,
#  'HalfBath': 0,
#  'BedroomAbvGr': 0,
#  'KitchenAbvGr': 0,
#  'KitchenQual': 'missing',
#  'TotRmsAbvGrd': 0,
#  'Functional': 'missing',
#  'Fireplaces': 0,
#  'FireplaceQu': 'missing',
#  'GarageType': 'missing',
#  'GarageYrBlt': 0,
#  'GarageFinish': 'missing',
#  'GarageCars': 0,
#  'GarageArea': 0,
#  'GarageQual': 'missing',
#  'GarageCond': 'missing',
#  'PavedDrive': 'missing',
#  'WoodDeckSF': 0,
#  'OpenPorchSF': 0,
#  'EnclosedPorch': 0,
#  '3SsnPorch': 0,
#  'ScreenPorch': 0,
#  'PoolArea': 0,
#  'PoolQC': 'missing',
#  'Fence': 'missing',
#  'MiscFeature': 'missing',
#  'MiscVal': 0,
#  'MoSold': 0,
#  'YrSold': 0,
#  'SaleType': 'missing',
#  'SaleCondition': 'missing',
#  'SalePrice': 0}

# %%
filtered_df = df.fillna(filling)

# %%
filtered_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave  missing      Reg
# 2             20       RL         80.0     9600   Pave  missing      Reg
# 3             60       RL         68.0    11250   Pave  missing      IR1
# 4             70       RL         60.0     9550   Pave  missing      IR1
# 5             60       RL         84.0    14260   Pave  missing      IR1
# ...          ...      ...          ...      ...    ...      ...      ...
# 1456          60       RL         62.0     7917   Pave  missing      Reg
# 1457          20       RL         85.0    13175   Pave  missing      Reg
# 1458          70       RL         66.0     9042   Pave  missing      Reg
# 1459          20       RL         68.0     9717   Pave  missing      Reg
# 1460          20       RL         75.0     9937   Pave  missing      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea   PoolQC    Fence  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0  missing  missing
# 2            Lvl    AllPub       FR2  ...        0  missing  missing
# 3            Lvl    AllPub    Inside  ...        0  missing  missing
# 4            Lvl    AllPub    Corner  ...        0  missing  missing
# 5            Lvl    AllPub       FR2  ...        0  missing  missing
# ...          ...       ...       ...  ...      ...      ...      ...
# 1456         Lvl    AllPub    Inside  ...        0  missing  missing
# 1457         Lvl    AllPub    Inside  ...        0  missing    MnPrv
# 1458         Lvl    AllPub    Inside  ...        0  missing    GdPrv
# 1459         Lvl    AllPub    Inside  ...        0  missing  missing
# 1460         Lvl    AllPub    Inside  ...        0  missing  missing
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        missing       0      2    2008        WD         Normal     208500
# 2        missing       0      5    2007        WD         Normal     181500
# 3        missing       0      9    2008        WD         Normal     223500
# 4        missing       0      2    2006        WD        Abnorml     140000
# 5        missing       0     12    2008        WD         Normal     250000
# ...          ...     ...    ...     ...       ...            ...        ...
# 1456     missing       0      8    2007        WD         Normal     175000
# 1457     missing       0      2    2010        WD         Normal     210000
# 1458        Shed    2500      5    2010        WD         Normal     266500
# 1459     missing       0      4    2010        WD         Normal     142125
# 1460     missing       0      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Broadcasting Operations
#
# Broadcasting functions are numpy's speciality. Since Pandas is built on top of nunpy so it also got this speciality.
#
# These are basically element wise operations, you do some arithmetic operation on array and it get implemented on all of it's elements

# %%
li = np.array([1,2,3,4,5])
li + 3
# Out:
# array([4, 5, 6, 7, 8])

# %%
# adding 10 to the `PoolArea` column
filtered_df.PoolArea = filtered_df.PoolArea + 10
filtered_df.head()
# that's why these arithmetic operations are called broadcasting operations
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  missing      Reg
# 2           20       RL         80.0     9600   Pave  missing      Reg
# 3           60       RL         68.0    11250   Pave  missing      IR1
# 4           70       RL         60.0     9550   Pave  missing      IR1
# 5           60       RL         84.0    14260   Pave  missing      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea   PoolQC    Fence  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...       10  missing  missing
# 2          Lvl    AllPub       FR2  ...       10  missing  missing
# 3          Lvl    AllPub    Inside  ...       10  missing  missing
# 4          Lvl    AllPub    Corner  ...       10  missing  missing
# 5          Lvl    AllPub       FR2  ...       10  missing  missing
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1      missing       0      2    2008        WD         Normal     208500
# 2      missing       0      5    2007        WD         Normal     181500
# 3      missing       0      9    2008        WD         Normal     223500
# 4      missing       0      2    2006        WD        Abnorml     140000
# 5      missing       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
# creating a new column from the sum of two already existing columns
filtered_df['MiscVal_MoSold'] = filtered_df['MiscVal'] + filtered_df['MoSold']
filtered_df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  missing      Reg
# 2           20       RL         80.0     9600   Pave  missing      Reg
# 3           60       RL         68.0    11250   Pave  missing      IR1
# 4           70       RL         60.0     9550   Pave  missing      IR1
# 5           60       RL         84.0    14260   Pave  missing      IR1
#
#    LandContour Utilities LotConfig  ...   PoolQC    Fence MiscFeature MiscVal  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...  missing  missing     missing       0
# 2          Lvl    AllPub       FR2  ...  missing  missing     missing       0
# 3          Lvl    AllPub    Inside  ...  missing  missing     missing       0
# 4          Lvl    AllPub    Corner  ...  missing  missing     missing       0
# 5          Lvl    AllPub       FR2  ...  missing  missing     missing       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice  MiscVal_MoSold
# Id
# 1       2   2008        WD         Normal     208500               2
# 2       5   2007        WD         Normal     181500               5
# 3       9   2008        WD         Normal     223500               9
# 4       2   2006        WD        Abnorml     140000               2
# 5      12   2008        WD         Normal     250000              12
#
# [5 rows x 81 columns]

# %%
filtered_df['MiscVal_MoSold'] = 15
filtered_df.head()
# no need to use loops, broadcasting is awesome :)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  missing      Reg
# 2           20       RL         80.0     9600   Pave  missing      Reg
# 3           60       RL         68.0    11250   Pave  missing      IR1
# 4           70       RL         60.0     9550   Pave  missing      IR1
# 5           60       RL         84.0    14260   Pave  missing      IR1
#
#    LandContour Utilities LotConfig  ...   PoolQC    Fence MiscFeature MiscVal  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...  missing  missing     missing       0
# 2          Lvl    AllPub       FR2  ...  missing  missing     missing       0
# 3          Lvl    AllPub    Inside  ...  missing  missing     missing       0
# 4          Lvl    AllPub    Corner  ...  missing  missing     missing       0
# 5          Lvl    AllPub       FR2  ...  missing  missing     missing       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice  MiscVal_MoSold
# Id
# 1       2   2008        WD         Normal     208500              15
# 2       5   2007        WD         Normal     181500              15
# 3       9   2008        WD         Normal     223500              15
# 4       2   2006        WD        Abnorml     140000              15
# 5      12   2008        WD         Normal     250000              15
#
# [5 rows x 81 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Statistical insights from data
#
# You've already seen the `describe` method, which gives you a good "summary" of the `DataFrame`. Let's explore other methods in more detail:

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
saleprice = df.SalePrice

# %%
saleprice
# Out:
# Id
# 1       208500
# 2       181500
# 3       223500
# 4       140000
# 5       250000
#          ...
# 1456    175000
# 1457    210000
# 1458    266500
# 1459    142125
# 1460    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
saleprice.min(), saleprice.max() # printing min and maximum values
# Out:
# (34900, 755000)

# %%
saleprice.sum() # printing sum of column
# Out:
# 264144946

# %%
saleprice.mean() # printing mean of column
# Out:
# 180921.19589041095

# %%
saleprice.std() # printing standard deviation of column
# Out:
# 79442.50288288663

# %%
saleprice.median() # printing median of column
# Out:
# 163000.0

# %%
saleprice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## More functions

# %% [markdown]
# ### Sorting

# %%
# sorting dataframe according to the values of column `SalePrice`
df.sort_values('SalePrice', ascending=False)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 692           60       RL        104.0    21535   Pave   NaN      IR1
# 1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1170          60       RL        118.0    35760   Pave   NaN      IR1
# 899           20       RL        100.0    12919   Pave   NaN      IR1
# 804           60       RL        107.0    13891   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 31            70  C (all)         50.0     8500   Pave  Pave      Reg
# 534           20       RL         50.0     5000   Pave   NaN      Reg
# 969           50       RM         50.0     5925   Pave   NaN      Reg
# 917           20  C (all)         50.0     9000   Pave   NaN      Reg
# 496           30  C (all)         60.0     7879   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 692          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 1183         Lvl    AllPub    Corner  ...      555     Ex  MnPrv         NaN
# 1170         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 899          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 804          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 31           Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 534          Low    AllPub    Inside  ...        0    NaN    NaN         NaN
# 969          Lvl    AllPub    Inside  ...        0    NaN   GdWo         NaN
# 917          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 496          Lvl    AllPub    Inside  ...        0    NaN   GdWo         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 692        0      1    2007        WD         Normal     755000
# 1183       0      7    2007        WD        Abnorml     745000
# 1170       0      7    2006        WD         Normal     625000
# 899        0      3    2010       New        Partial     611657
# 804        0      1    2009       New        Partial     582933
# ...      ...    ...     ...       ...            ...        ...
# 31         0      7    2008        WD         Normal      40000
# 534        0      1    2007        WD         Normal      39300
# 969        0      5    2009        WD        Abnorml      37900
# 917        0     10    2006        WD        Abnorml      35311
# 496        0     11    2009        WD        Abnorml      34900
#
# [1460 rows x 80 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### grouping the data according to a column

# %%
new_df.head(10)
# Out:
#         Date         Tag  Posts
# 0 2008-07-01          c#      3
# 1 2008-08-01    assembly      8
# 2 2008-08-01  javascript    162
# 3 2008-08-01           c     85
# 4 2008-08-01      python    124
# 5 2008-08-01        perl     28
# 6 2008-08-01          c#    511
# 7 2008-08-01         c++    164
# 8 2008-08-01        java    222
# 9 2008-08-01      delphi     14

# %%
new_df.shape
# Out:
# (1991, 3)

# %%
# grouping the data and applying some operation on it
new_df.groupby('Tag').count()
# try it with mean() too :)
# Out:
#             Date  Posts
# Tag
# assembly     144    144
# c            144    144
# c#           145    145
# c++          144    144
# delphi       144    144
# go           129    129
# java         144    144
# javascript   144    144
# perl         144    144
# php          144    144
# python       144    144
# r            142    142
# ruby         144    144
# swift        135    135

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### plotting graph

# %%
# plotting bar graph
plot_df.plot(y='SalePrice', x='YrSold', kind='bar',figsize=(16,10))
# Out:
# <AxesSubplot:xlabel='YrSold'>

# %%
# plotting scatter graph
plot_df.plot(y='SalePrice', x='HouseStyle', kind='scatter')
# Out:
# <AxesSubplot:xlabel='HouseStyle', ylabel='SalePrice'>

# %% [markdown]
# # The End !!

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
